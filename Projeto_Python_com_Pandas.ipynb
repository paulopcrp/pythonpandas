# %% [markdown]
# # **Projeto do Bootcamp Analise de dados com Python e Pandas**
# Paulo Cesar Rodrigues - PC
# setembro/2022

# %%
#importando a biblioteca Pandas
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/PUC-Pós/DataSets/Gapminder.csv", error_bad_lines=False, sep=";")

# %%
#visualizar uma quantidade de linhas
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df = df.rename(columns={"country":"Pais","continent":"Continente","year":"Ano","lifeExp":"Expectativa de vida","pop":"Populacao Total", "gdpPercap":"PIB"})

# %%
#exibindo as 10 primeiras linhas no DataFrame
df.head(10)
# Out:
#           Pais Continente   Ano  Expectativa de vida  Populacao Total  \
# 0  Afghanistan       Asia  1952               28.801          8425333
# 1  Afghanistan       Asia  1957               30.332          9240934
# 2  Afghanistan       Asia  1962               31.997         10267083
# 3  Afghanistan       Asia  1967               34.020         11537966
# 4  Afghanistan       Asia  1972               36.088         13079460
# 5  Afghanistan       Asia  1977               38.438         14880372
# 6  Afghanistan       Asia  1982               39.854         12881816
# 7  Afghanistan       Asia  1987               40.822         13867957
# 8  Afghanistan       Asia  1992               41.674         16317921
# 9  Afghanistan       Asia  1997               41.763         22227415
#
#           PIB
# 0  779.445314
# 1  820.853030
# 2  853.100710
# 3  836.197138
# 4  739.981106
# 5  786.113360
# 6  978.011439
# 7  852.395945
# 8  649.341395
# 9  635.341351

# %%
#total de linhas e colunas no conjunto de dados
#retorna so as colunas df.columbs
#retorna o tipo de dados df.types
df.shape
# Out:
# (3312, 6)

# %%
#ultimas linhas do conjunto de dados
df.tail(15)
# Out:
#           Pais Continente   Ano  Expectativa de vida  Populacao Total  \
# 3297    Zambia     Africa  1997               40.238          9417789
# 3298    Zambia     Africa  2002               39.193         10595811
# 3299    Zambia     Africa  2007               42.384         11746035
# 3300  Zimbabwe     Africa  1952               48.451          3080907
# 3301  Zimbabwe     Africa  1957               50.469          3646340
# 3302  Zimbabwe     Africa  1962               52.358          4277736
# 3303  Zimbabwe     Africa  1967               53.995          4995432
# 3304  Zimbabwe     Africa  1972               55.635          5861135
# 3305  Zimbabwe     Africa  1977               57.674          6642107
# 3306  Zimbabwe     Africa  1982               60.363          7636524
# 3307  Zimbabwe     Africa  1987               62.351          9216418
# 3308  Zimbabwe     Africa  1992               60.377         10704340
# ...

# %%
#retorna informações estatisticas
df.describe()
# Out:
#                Ano  Expectativa de vida  Populacao Total            PIB
# count  3312.000000          3312.000000     3.312000e+03    3312.000000
# mean   1980.301630            65.246871     3.161489e+07   11317.115805
# std      16.927294            11.768412     1.041193e+08   11369.142739
# min    1950.000000            23.599000     5.941200e+04     241.165876
# 25%    1967.000000            58.337500     2.678572e+06    2514.625266
# 50%    1982.000000            69.610000     7.557218e+06    7838.505123
# 75%    1996.000000            73.657750     1.958522e+07   17357.879170
# max    2007.000000            82.670000     1.318683e+09  113523.132900

# %%
#ver os continentes
df["Continente"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', nan, 'FSU', 'Oceania'],
#       dtype=object)

# %%
america = df.loc[df["Continente"] == "Americas"]
america.head()
# Out:
#          Pais Continente   Ano  Expectativa de vida  Populacao Total  \
# 48  Argentina   Americas  1952               62.485         17876956
# 49  Argentina   Americas  1957               64.399         19610538
# 50  Argentina   Americas  1962               65.142         21283783
# 51  Argentina   Americas  1967               65.634         22934225
# 52  Argentina   Americas  1972               67.065         24779799
#
#             PIB
# 48  5911.315053
# 49  6856.856212
# 50  7133.166023
# 51  8052.953021
# 52  9443.038526

# %%
df.groupby("Continente")["Pais"].nunique()
# Out:
# Continente
# Africa      51
# Americas    25
# Asia        41
# Europe      35
# FSU          6
# Oceania      3
# Name: Pais, dtype: int64

# %%
df.groupby("Ano")["Expectativa de vida"].mean()
# Out:
# Ano
# 1950    62.002568
# 1951    65.904167
# 1952    49.206867
# 1953    66.674563
# 1954    67.459817
# 1955    67.806757
# 1956    67.950637
# 1957    51.614590
# 1958    68.815936
# 1959    68.226579
# 1960    68.470837
# 1961    68.862480
# 1962    54.035234
# 1963    69.595735
# 1964    70.063105
# 1965    70.259881
# 1966    70.447526
# 1967    56.263629
# 1968    70.689081
# 1969    70.653896
# 1970    70.961141
# 1971    71.103976
# 1972    58.474481
# 1973    71.500338
# 1974    71.778504
# 1975    71.939218
# 1976    72.158050
# 1977    60.429090
# 1978    72.717567
# 1979    73.018717
# 1980    73.064524
# 1981    73.337399
# 1982    62.365871
# 1983    73.787778
# 1984    74.100741
# 1985    74.112222
# 1986    74.452222
# 1987    63.984860
# 1988    74.760000
# 1989    74.924444
# 1990    74.283438
# 1991    74.374848
# 1992    65.008443
# 1993    74.324545
# 1994    74.456667
# 1995    74.552727
# 1996    75.029394
# 1997    65.873799
# 1998    75.569697
# ...

# %% [markdown]
# Trabalhando com Planilhas Excel
#
#
# /

# %%
#importando a bliblioteca
import pandas as pd

# %%
#Lendo as planilhas
df1 = pd.read_excel("/content/drive/MyDrive/PUC-Pós/DataSets/Aracaju.xlsx")
df2 = pd.read_excel("/content/drive/MyDrive/PUC-Pós/DataSets/Fortaleza.xlsx")
df3 = pd.read_excel("/content/drive/MyDrive/PUC-Pós/DataSets/Natal.xlsx")
df4 = pd.read_excel("/content/drive/MyDrive/PUC-Pós/DataSets/Recife.xlsx")
df5 = pd.read_excel("/content/drive/MyDrive/PUC-Pós/DataSets/Salvador.xlsx")

# %%
df1.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
#exibindo as ultimas 5 linhas
df1.tail()
# Out:
#       Cidade       Data  Vendas  LojaID  Qtde
# 125  Aracaju 2018-01-01   15.62    1522     2
# 126  Aracaju 2018-01-01   13.41    1520     7
# 127  Aracaju 2018-01-01   33.12    1522     9
# 128  Aracaju 2018-01-01   37.49    1521     2
# 129  Aracaju 2018-01-01   13.70    1522     6

# %%
#verificando o tipo de dado de cada linha
df1.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
df1.sample(5)
# Out:
#      Cidade       Data  Vendas  LojaID  Qtde
# 32  Aracaju 2018-01-01   42.97    1522     6
# 26  Aracaju 2018-01-01    6.98    1521    10
# 35  Aracaju 2018-01-01   40.60    1520     3
# 2   Aracaju 2018-01-01   71.55    1520     1
# 41  Aracaju 2018-01-01  229.64    1520     8

# %%
#alterando tipo de dado de uma coluna
df1["LojaID"] = df1["LojaID"].astype("object")

# %%
df1.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00   1520     1
# 1  Aracaju 2018-01-01   14.21   1522     6
# 2  Aracaju 2018-01-01   71.55   1520     1
# 3  Aracaju 2018-01-01    3.01   1521     7
# 4  Aracaju 2018-01-01   24.51   1522     8

# %%
#verificar valores nulos
df1.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
#substituindo valores nulos
df1["Vendas"].fillna(df1["Vendas"].mean(), inplace=True)

# %%
df1.sample(15)
# Out:
#       Cidade       Data  Vendas LojaID  Qtde
# 112  Aracaju 2018-01-01    4.52   1522     8
# 21   Aracaju 2018-01-01   37.36   1520     2
# 90   Aracaju 2018-01-01   16.27   1522     1
# 72   Aracaju 2018-01-01  168.95   1523     7
# 64   Aracaju 2018-01-01   21.00   1523     5
# 71   Aracaju 2018-01-01  228.27   1523     6
# 66   Aracaju 2018-01-01   76.59   1523     4
# 48   Aracaju 2018-01-01   35.90   1521     8
# 84   Aracaju 2018-01-01   40.98   1520     5
# 43   Aracaju 2018-01-01   19.63   1523     9
# 10   Aracaju 2019-01-01   42.34   1522     6
# 89   Aracaju 2018-01-01   10.15   1523     7
# 4    Aracaju 2018-01-01   24.51   1522     8
# 33   Aracaju 2018-01-01   35.09   1523     4
# 9    Aracaju 2019-01-01  149.36   1523     3

# %%
#juntando todos os arquivos
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
#verificando a media de vendas
df["Vendas"].mean()
# Out:
# 122.61180089485458

# %%
#apagando valores nulos
df.dropna(inplace=True)

# %% [markdown]
# Trabalhando com datas

# %%
#transformar a coluna de data em um tipo inteiro
df["Data"] = df["Data"].astype("int64")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.

# %%
df.dtypes
# Out:
# Cidade     object
# Data        int64
# Vendas    float64
# LojaID     object
# Qtde        int64
# dtype: object

# %%
#transformar a coluna de data em data
df["Data"] = pd.to_datetime(df["Data"])

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
#agrupar por ano
df.groupby(df["Data"].dt.year)

# %% [markdown]
# Analise exploratória

# %%
#importanto a biblioteca
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
#fazendo o upload
from google.colab import files
arq = files.upload()
# Out:
#      <input type="file" id="files-0d788bb4-ba2f-4315-8741-760e1144c1d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d788bb4-ba2f-4315-8741-760e1144c1d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#criando um dataframe
df = pd.read_excel("AdventureWorks.xlsx")

# %%
#visualinaod as primeiras linhas
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
# 2          348.58           758.0           6             0.0       4548.0
# 3          348.58           758.0           6             0.0       4548.0
# 4          348.58           758.0           6             0.0       4548.0
#
# ...

# %%
#quantidade de linhas e colunas
df.shape
# Out:
# (904, 16)

# %%
#verificando os tipos de dados
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object
